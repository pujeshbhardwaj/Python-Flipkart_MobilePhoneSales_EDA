# %% [markdown]
# # Project Title - Flipkart_mobile_data_analysis
#
# The data used in this analysis was flipkart sales data of all the mobile brands which there is detailed about the mobile brand, model, color, selling price, original price memory, storage etc, this data I have extracted from Kaggle as advised by this course to which I have also uploaded the link to this data source at the end at reference ,In this project of exploratory analysis was focused on identifying the diffrent brands and their range of prices, also analysed which is the most popular brand along with the most popular model of mobile phone brand, in order to find this I used pandas to upload data in tabular form and to do data cleaning also performed a mathematical operation then with the help of libraries like seaborn, matlotlib etc I did data visualization to better understand the data and finding inferences. This final assignment helped me a lot to utilizing what I learned in the course practically and also help me to develop my own ideas and understanding to data analysis.

# %% [markdown]
# ## Downloading the Dataset
#
# **TODO** - Can upload data directly from kaggle course but I first downloaded it to my system then uploaded to jupyter note book by pd.read_csv function. This data consist of flipkart mobile sales of various brands and other details.

# %%
import pandas as pd

# %% [markdown]
# Let's begin by downloading the data, and listing the files within the dataset.

# %%
fkt_df =  pd.read_csv('Flipkart_mobile_brands_scraped_data.csv')

# %%
fkt_df
# Out:
#        Brand      Model            Color Memory Storage  Rating  \
# 0       OPPO        A53  Moonlight Black   4 GB   64 GB     4.5
# 1       OPPO        A53       Mint Cream   4 GB   64 GB     4.5
# 2       OPPO        A53  Moonlight Black   6 GB  128 GB     4.3
# 3       OPPO        A53       Mint Cream   6 GB  128 GB     4.3
# 4       OPPO        A53   Electric Black   4 GB   64 GB     4.5
# ...      ...        ...              ...    ...     ...     ...
# 2642  Xiaomi  Redmi Y3          Bold Red   4 GB   64 GB     4.3
# 2643  Xiaomi  Redmi Y3      Elegant Blue   3 GB   32 GB     4.3
# 2644  Xiaomi  Redmi Y3      Elegant Blue   4 GB   64 GB     4.2
# 2645  Xiaomi  Redmi Y3       Prime Black   3 GB   32 GB     4.2
# 2646  Xiaomi  Redmi Y3       Prime Black   4 GB   64 GB     4.3
#
#       Selling_Price  Original_Price
# 0           11990.0         15990.0
# 1           11990.0         15990.0
# 2           13990.0         17990.0
# 3           13990.0         17990.0
# ...

# %% [markdown]
# The dataset has been downloaded and extracted.

# %%
type(fkt_df)
# Out:
# pandas.core.frame.DataFrame

# %%
fkt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2647 entries, 0 to 2646
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Brand           2647 non-null   object
#  1   Model           2645 non-null   object
#  2   Color           2505 non-null   object
#  3   Memory          2605 non-null   object
#  4   Storage         2568 non-null   object
#  5   Rating          2647 non-null   float64
#  6   Selling_Price   2644 non-null   float64
#  7   Original_Price  969 non-null    float64
# dtypes: float64(3), object(5)
# memory usage: 165.6+ KB

# %% [markdown]
# Let us save and upload our work to Jovian before continuing.

# %%
project_name = "Flipkart_mobile_data_analysis"

# %% [markdown]
# ## Data Preparation and Cleaning
#
# - Lets describe the complete data in order to have general understanding about data (Count, Mean, std etc) we may require later for our reference
# - we also use head for top 5 results we can also use tail to view bottom 5 data
# - we also use '.sample' for obtaining some random data set
# - I have also done grouping by brand in order to count which brand is sold the most, grouping by memory in order to count how much ram memory generally prefer by customers, grouping by color in order to count which color is liked by people the most and finally grouping by color in order to count which color is liked by people the most
# - Like numpy pandas also support sum function so I used sum function to calculate the total sale grouping by color in order to count which color is liked by people the most

# %%
# Lets describe the complete data in order to have general understanding about data (Count, Mean, std etc) we may require later frr our refrence
fkt_df.describe().T
# Out:
#                  count          mean           std     min      25%      50%  \
# Rating          2647.0      4.001700      0.997499     0.0      4.0      4.3
# Selling_Price   2644.0  26461.362330  29833.135164  1000.0   9490.0  14999.0
# Original_Price   969.0  29852.605779  27659.141051  1599.0  12999.0  18999.0
#
#                      75%       max
# Rating              4.40       5.0
# Selling_Price   29998.25  179900.0
# Original_Price  34999.00  189999.0

# %%
#Use of head for top 5 results we can also use tali to view bottom 5 data
fkt_df.head()
# Out:
#   Brand Model            Color Memory Storage  Rating  Selling_Price  \
# 0  OPPO   A53  Moonlight Black   4 GB   64 GB     4.5        11990.0
# 1  OPPO   A53       Mint Cream   4 GB   64 GB     4.5        11990.0
# 2  OPPO   A53  Moonlight Black   6 GB  128 GB     4.3        13990.0
# 3  OPPO   A53       Mint Cream   6 GB  128 GB     4.3        13990.0
# 4  OPPO   A53   Electric Black   4 GB   64 GB     4.5        11990.0
#
#    Original_Price
# 0         15990.0
# 1         15990.0
# 2         17990.0
# 3         17990.0
# 4         15990.0

# %%
# can use '.sample' for obtaing some random data set
fkt_df.sample(10)
# Out:
#          Brand            Model               Color Memory Storage  Rating  \
# 848     GIONEE        M7 Power                 Gold   4 GB   64 GB     4.1
# 2261    Lenovo              P2   Grey/Graphite Grey   3 GB   32 GB     4.3
# 911      Nokia      TA-1010/105                 NaN   4 MB    4 MB     4.2
# 1824   SAMSUNG              Z2                Black   1 GB    8 GB     3.6
# 1605   SAMSUNG      Galaxy M11               Violet   3 GB   32 GB     4.2
# 2391  Motorola               G6        Indigo Black   3 GB   32 GB     4.2
# 1244     Apple  iPhone 6s Plus                 Gold   2 GB     NaN     4.4
# 1978   SAMSUNG         On7 Pro                 Gold   2 GB   16 GB     4.1
# 873     GIONEE             S11           Royal Blue   4 GB   64 GB     2.8
# 1508   SAMSUNG      Galaxy F12      Celestial Black   4 GB  128 GB     4.2
#
#       Selling_Price  Original_Price
# 848         15399.0             NaN
# 2261        16999.0             NaN
# ...

# %%
#grouping by brand in order to count which brand is sold the most
fkt_df['Brand'].groupby(fkt_df['Brand']).count().sort_values(ascending=False)
# Out:
# Brand
# SAMSUNG         695
# Apple           364
# realme          285
# OPPO            244
# Nokia           212
# Xiaomi          164
# GIONEE          129
# Lenovo          121
# ASUS            113
# Motorola        105
# LG               99
# vivo             57
# Google Pixel     29
# POCO             20
# HTC               5
# IQOO              5
# Name: Brand, dtype: int64

# %%
#grouping by memory in order to count how much ram memory generally prefer by customers
fkt_df['Brand'].groupby(fkt_df['Memory']).count().sort_values(ascending=False)
# Out:
# Memory
# 4 GB      631
# 3 GB      445
# 6 GB      381
# 2 GB      345
# 8 GB      264
# 1 GB      175
# 4GB       114
# 12 GB      45
# 4 MB       39
# 512 MB     33
# 1.5 GB     27
# 64 MB      16
# 16 MB      16
# 32 MB      14
# 8 MB       14
# 6GB        11
# 128 MB      6
# 768 MB      6
# 100 MB      3
# 10 MB       3
# 0.5 GB      2
# 256 MB      2
# 2 MB        2
# 46 MB       2
# 16 GB       2
# 717 MB      2
# 30 MB       1
# 32 GB       1
# 18 GB       1
# 153 MB      1
# 0 MB        1
# Name: Brand, dtype: int64

# %%
#Like numpy pandas also support sum function
#Using sum function to calculate the total sale
total_sales = fkt_df.Selling_Price.sum()
total_sales
# Out:
# 69963842.0

# %%
#grouping by color in order to count which color is liked by people the most
fkt_df['Color'].groupby(fkt_df['Color']).count().sort_values(ascending=False)
# Out:
# Color
# Black               328
# Gold                182
# White               150
# Blue                141
# Silver               97
#                    ...
# Grey/Flash Gray       1
# Grey/Dark Grey        1
# Grey / Silver         1
# Grey / Dark Grey      1
# midnight blue         1
# Name: Color, Length: 531, dtype: int64

# %% [markdown]
# ## Exploratory Analysis and Visualization
#
# **TODO** - write some explanation here.

# %% [markdown]
# Let's begin by importing`matplotlib.pyplot` and `seaborn`.

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# Plotted a graph of pairplot of brand to understand the pricing and rating of different brands.
# It can be understood in below obtained graph that samsung, apple and oppo are brands that have relatively higher rating and
# and most of the brand price range lies between 15000 to 30000 most.

# %%
sns.set_style("white")

# %%
sns.pairplot(fkt_df, hue='Brand');

# %% [markdown]
# Also plotted below displot to show how count of selling price and original price the motive to show this plotting is to understand the market saturation of brands on relation to pricing and finally after seeing the bar plot we can conclude, "It is quite clear that the market is saturated with lower to mid range cost phones i.e. <25000 INR"

# %%
sns.displot(fkt_df, x='Selling_Price',bins=[5000,10000,15000,20000,25000,30000,35000,40000,50000,60000,80000], aspect=1.2,color='#fd6c9e')

# %%
sns.displot(fkt_df, x='Original_Price',bins=[5000,10000,15000,20000,25000,30000,35000,40000,50000,60000,80000], aspect=1.2,color='#ff8243')

# %%
# So this can be said that the market is saturated with lower to mid range cost phones i.e. <25000 INR"

# %% [markdown]
# **IN** Below two graphs I have tried to figure out which brand counts to what level in terms of selling price or from this we are able to conclude that samsung is the top selling brand in numbers in range of <25000 followed by realme and brands like oppo, pocco, vivo and Xiaomi.
#
# In another graph I have simply shown the no of phones(brands) sold and can be seen samsung is on top followed by apple then realme and then others

# %%
#brandwise mobile phone price segments
sns.displot(fkt_df, x='Selling_Price',bins=5, hue='Brand',aspect=1.5)

# %%
# barplot showing the counts of mobile as per brand
fig, ax = plt.subplots(figsize=(15,3))
ax=sns.countplot(x="Brand", data=fkt_df)

# %% [markdown]
# **TODO** In below two graph I will use stripplot to show ratings of various brands of mobiles, we use this graph in order to clearly define through visualization that how rating trends from high to low and varies with brands.
# In another simillar graph we did the same thing with selling price of brands.

# %%
#In below graph we can conclude that people are either liking the phone or they dont like it at all, by giving either highest
#rating or the lowest rating beacause no rating lies between 1-2 and very few of brand like motorola, geonee and xiomi lies 
#between 2-3.
#it was asloto be noted that apple mostly have rating between 4.5 to 5 consistantly which is quite high
fig, ax = plt.subplots(figsize=(18,5))
ax = sns.stripplot(y="Rating", x="Brand", data=fkt_df)

# %%
#This can be seen in below graph that apple have selling price range from 175000-50000 which is highest and dosent have price
#range below 30000, samsung have phones of almost all selling price range , and other most of the phones selling price range
#is below 25000
fig, ax = plt.subplots(figsize=(18,5))
ax = sns.stripplot(y="Selling_Price", x="Brand", data=fkt_df)

# %% [markdown]
# **TODO** In below two graphs we showed density of brand wise counts of mobiles where most of the phones models are below 25000 range
# And a pie plot to clearly show the percentage of mobile phones sold samsung have the highest market share followed by apple and realme.

# %%
fig, ax = plt.subplots(figsize=(17,6))
ax = sns.boxplot(x="Brand", y="Selling_Price", data=fkt_df)

# %% [markdown]
# In below two graphs we showed density of brand wise counts of mobiles where most of the phones models are below 25000 range, And it can be clearly seen that All the phones of google pixel and apple lie in the range of 50-75k and 50-125k range

# %%
Brand_counts = fkt_df.Brand.value_counts()
Brand_counts
plt.figure(figsize=(15,8))
plt.title('distribution of mobile sold as per brand')
plt.pie(Brand_counts, labels=Brand_counts.index, autopct='%1.1f%%', startangle=180);

# %% [markdown]
# the percentage of mobile phones sold samsung have the highest market share followed by apple and realme.

# %% [markdown]
# Let us save and upload our work to Jovian before continuing

# %% [markdown]
# ## Asking and Answering Questions
#
# TODO - Here in this exercise I have ask various questions and answer to these question is provided by performing the python programing and answered below, the questions asked are.
# - Q1:What is the average selling price of Apple mobile phone
# - Q2:Find the total number of models of brands mobile phones
# - Q3:Find the top 15 sold model and which is the highest  and lowest sold model with its count
# - Q4:Find the mobile phones detail of price > 15000 and name the one other than apple
# - Q5:Add a new column to the existing data which shows the Status of phone to be sold

# %% [markdown]
# #### Q1: TODO - What is the average selling price of Apple mobile phone

# %%
fkt_df
# Out:
#        Brand      Model            Color Memory Storage  Rating  \
# 0       OPPO        A53  Moonlight Black   4 GB   64 GB     4.5
# 1       OPPO        A53       Mint Cream   4 GB   64 GB     4.5
# 2       OPPO        A53  Moonlight Black   6 GB  128 GB     4.3
# 3       OPPO        A53       Mint Cream   6 GB  128 GB     4.3
# 4       OPPO        A53   Electric Black   4 GB   64 GB     4.5
# ...      ...        ...              ...    ...     ...     ...
# 2642  Xiaomi  Redmi Y3          Bold Red   4 GB   64 GB     4.3
# 2643  Xiaomi  Redmi Y3      Elegant Blue   3 GB   32 GB     4.3
# 2644  Xiaomi  Redmi Y3      Elegant Blue   4 GB   64 GB     4.2
# 2645  Xiaomi  Redmi Y3       Prime Black   3 GB   32 GB     4.2
# 2646  Xiaomi  Redmi Y3       Prime Black   4 GB   64 GB     4.3
#
#       Selling_Price  Original_Price
# 0           11990.0         15990.0
# 1           11990.0         15990.0
# 2           13990.0         17990.0
# 3           13990.0         17990.0
# ...

# %%
# Brandwise Mean Selling prices
fkt_df.groupby('Brand')['Selling_Price'].mean().sort_values(ascending=False)
# Out:
# Brand
# Apple           78065.142857
# Google Pixel    61391.862069
# IQOO            37190.000000
# SAMSUNG         23829.929496
# HTC             23797.200000
# vivo            23271.250000
# LG              19323.181818
# ASUS            18728.491071
# OPPO            18677.242798
# Motorola        16357.466667
# Xiaomi          15540.378049
# realme          15535.645614
# POCO            12649.000000
# Lenovo          10083.842975
# Nokia            9251.490566
# GIONEE           7135.093023
# Name: Selling_Price, dtype: float64

# %% [markdown]
# #### The average selling price of apple mobile is 78065.142857

# %% [markdown]
# #### Q2: TODO - Find the total number of models of brands mobile phones

# %% [markdown]
# To ans this quest we will use .nunique function

# %%
fkt_df.Model.nunique()
# Out:
# 773

# %% [markdown]
# ### The total no of Models of brand are 773

# %% [markdown]
# #### Q3: TODO - Find the top 15 sold model and which is the highest  and lowest sold model with its count

# %%
top_mobile_model = fkt_df.Model.value_counts().head(15)
top_mobile_model
# Out:
# iPhone 11             36
# 3                     27
# iPhone XR             27
# iPhone 7              22
# iPhone 11 Pro         21
# iPhone 7 Plus         20
# Galaxy A12            19
# iPhone 12             18
# iPhone 6s             18
# iPhone 13 Pro Max     18
# iPhone 12 Mini        18
# iPhone SE             17
# 1                     17
# Zenfone Selfie        16
# iPhone 6s Plus        16
# Name: Model, dtype: int64

# %% [markdown]
# ### The highest sold model is iphone 11 = 30

# %% [markdown]
# ### The Lowest sold model is iphone 6s plus and zenfone selfie = 16

# %% [markdown]
# #### Q4: TODO - Find the mobile phones detail of price > 15000 and name the one other than apple

# %%
highest_price = fkt_df.Selling_Price > 150000

# %%
highest_price
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2642    False
# 2643    False
# 2644    False
# 2645    False
# 2646    False
# Name: Selling_Price, Length: 2647, dtype: bool

# %%
fkt_df[highest_price]
# Out:
#         Brand               Model           Color Memory Storage  Rating  \
# 1234    Apple  iPhone 13 Pro Max      Sierra Blue   6 GB    1 TB     0.0
# 1256    Apple  iPhone 13 Pro Max             Gold   6 GB     NaN     0.0
# 1315    Apple  iPhone 13 Pro Max             Gold   6 GB  512 GB     0.0
# 1352    Apple  iPhone 13 Pro Max             Gold   6 GB    1 TB     0.0
# 1385    Apple  iPhone 11 Pro Max   Midnight Green    4GB  512 GB     4.7
# 1393    Apple  iPhone 11 Pro Max       Space Grey    4GB  512 GB     4.7
# 1394    Apple      iPhone 13 Pro         Graphite   6 GB    1 TB     0.0
# 1398    Apple      iPhone 13 Pro           Silver   6 GB    1 TB     0.0
# 1402    Apple      iPhone 13 Pro      Sierra Blue   6 GB    1 TB     0.0
# 1404    Apple  iPhone 13 Pro Max           Silver   6 GB  512 GB     0.0
# 1405    Apple  iPhone 11 Pro Max           Silver    4GB  512 GB     4.7
# 1406    Apple  iPhone 13 Pro Max      Sierra Blue   6 GB  512 GB     0.0
# ...

# %% [markdown]
# ### The phone above 150000 range sp other than apple are 3 models of samsung galaxy Z Fold3 5G and Fold 2 5G

# %% [markdown]
# #### Q5: TODO - Add a new column to the existing data which shows the Status of phone to be sold

# %%
fkt_df['Status'] = "sold"

# %%
fkt_df
# Out:
#        Brand      Model            Color Memory Storage  Rating  \
# 0       OPPO        A53  Moonlight Black   4 GB   64 GB     4.5
# 1       OPPO        A53       Mint Cream   4 GB   64 GB     4.5
# 2       OPPO        A53  Moonlight Black   6 GB  128 GB     4.3
# 3       OPPO        A53       Mint Cream   6 GB  128 GB     4.3
# 4       OPPO        A53   Electric Black   4 GB   64 GB     4.5
# ...      ...        ...              ...    ...     ...     ...
# 2642  Xiaomi  Redmi Y3          Bold Red   4 GB   64 GB     4.3
# 2643  Xiaomi  Redmi Y3      Elegant Blue   3 GB   32 GB     4.3
# 2644  Xiaomi  Redmi Y3      Elegant Blue   4 GB   64 GB     4.2
# 2645  Xiaomi  Redmi Y3       Prime Black   3 GB   32 GB     4.2
# 2646  Xiaomi  Redmi Y3       Prime Black   4 GB   64 GB     4.3
#
#       Selling_Price  Original_Price Status
# 0           11990.0         15990.0   sold
# 1           11990.0         15990.0   sold
# 2           13990.0         17990.0   sold
# ...

# %% [markdown]
# ### In above table we can clearly see a new column "status" added with sold results

# %% [markdown]
# Let us save and upload our work to Jovian before continuing.

# %% [markdown]
# ## Inferences and Conclusion
#
# **TODO** - The data used in this analysis was flipkart sales data of all the mobile brands which there is detailed about the mobile brand, model, color, selling price, original price memory, storage etc, in which my exploratory analysis was focused on identifying the diffrent brands and their range of prices, some of the infrences from my analysis are:
# -  It can be understood in below obtained graph that samsung, apple and oppo are brands that have relatively higher rating and and most of the brand price range lies between 15000 to 30000 most.
# - It is quite clear that the market is saturated with lower to mid range cost phones i.e. <25000 INR"
# - samsung is the top selling brand in numbers in range of <25000 followed by realme and brands like oppo, pocco, vivo and Xiaomi.
# - The no of phones(brands) sold and can be seen samsung is on top followed by apple then realme and then others
# - people are either liking the phone or they dont like it at all, by giving either highest rating or the lowest rating beacause no rating lies between 1-2 and very few of brand like motorola, geonee and xiomi lies between 2-3.
# - it was asloto be noted that apple mostly have rating between 4.5 to 5 consistantly which is quite high
# - samsung have phones of almost all selling price range , and other most of the phones selling price range is below 25000
# -  All the phones of google pixel and apple lie in the range of 50-75k and 50-125k range
# - The percentage of mobile phones sold samsung have the highest market share followed by apple and realme.
# #### The conclusion of my analysis is that the samsung phones is the most sold phone but apple have the highest rating, most of the mobile phones lies in the selling price range of <25000 and apple does not sell phone in that price range, and finally apple has the most number of sold single model.

# %% [markdown]
# ## References and Future Work
#
# **TODO** - My analysis of exploratory analysis work was limited to the brand of mobile pone with respect to selling price and original price but for further analysis can be done with relation of brand to the colour, its model, memory, its storage and rating and predictive analysis can also be done with the help of available data.
# #### Reference : this data was taken through kaggle platform the link to it is "https://www.kaggle.com/devsubhash/flipkart-mobiles-eda/data''
